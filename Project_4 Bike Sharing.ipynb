# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings

# %%
df=pd.read_csv("day.csv")
df.head(20)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1        0        6           0
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# ...

# %%
df.drop('instant',axis=1,inplace=True)

# %%
df.drop('dteday',axis=1,inplace=True)

# %%
fig = plt.figure(figsize = (12,8))
sb.barplot(x = 'holiday', y = 'cnt', data = df)
#more bikes used in weekends

# %%
fig = plt.figure(figsize = (12,8))
sb.barplot(x = 'workingday', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,8))
sb.barplot(x = 'weekday', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,8))
sb.barplot(x = 'season', y = 'cnt', data = df)
#more bikes used in summer
#least in winter

# %%
fig = plt.figure(figsize = (12,12))
sb.barplot(x = 'weathersit', y = 'cnt', data = df)
# more used in clear environment and less used in heavy rains

# %%
fig = plt.figure(figsize = (12,12))
sb.lineplot(x = 'temp', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sb.lineplot(x = 'atemp', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sb.lineplot(x = 'hum', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,12))
sb.lineplot(x = 'windspeed', y = 'cnt', data = df)

# %%
fig = plt.figure(figsize = (12,8))
sb.barplot(x = 'yr', y = 'cnt', data = df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
# instant       731 non-null int64
# dteday        731 non-null object
# season        731 non-null int64
# yr            731 non-null int64
# mnth          731 non-null int64
# holiday       731 non-null int64
# weekday       731 non-null int64
# workingday    731 non-null int64
# weathersit    731 non-null int64
# temp          731 non-null float64
# atemp         731 non-null float64
# hum           731 non-null float64
# windspeed     731 non-null float64
# casual        731 non-null int64
# registered    731 non-null int64
# cnt           731 non-null int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
df.shape
# Out:
# (731, 16)

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
dfcor=df.corr()
dfcor
# Out:
#              instant    season        yr      mnth   holiday   weekday  \
# instant     1.000000  0.412224  0.866025  0.496702  0.016145 -0.000016
# season      0.412224  1.000000 -0.001844  0.831440 -0.010537 -0.003080
# yr          0.866025 -0.001844  1.000000 -0.001792  0.007954 -0.005461
# mnth        0.496702  0.831440 -0.001792  1.000000  0.019191  0.009509
# holiday     0.016145 -0.010537  0.007954  0.019191  1.000000 -0.101960
# weekday    -0.000016 -0.003080 -0.005461  0.009509 -0.101960  1.000000
# workingday -0.004337  0.012485 -0.002013 -0.005901 -0.253023  0.035790
# weathersit -0.021477  0.019211 -0.048727  0.043528 -0.034627  0.031087
# temp        0.150580  0.334315  0.047604  0.220205 -0.028556 -0.000170
# atemp       0.152638  0.342876  0.046106  0.227459 -0.032507 -0.007537
# hum         0.016375  0.205445 -0.110651  0.222204 -0.015937 -0.052232
# windspeed  -0.112620 -0.229046 -0.011817 -0.207502  0.006292  0.014282
# ...

# %%
sb.heatmap(dfcor)

# %%
sb.heatmap?
plt.figure(figsize=(10,6))
sb.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %%
collist=df.columns.values
ncol=14
nrows=10

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#separating the input variable
import numpy as np
df_x=df.drop(columns=["dteday"])
df_x
# Out:
#      instant  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0          1       1   0     1        0        6           0           2
# 1          2       1   0     1        0        0           0           2
# 2          3       1   0     1        0        1           1           1
# 3          4       1   0     1        0        2           1           1
# 4          5       1   0     1        0        3           1           1
# ..       ...     ...  ..   ...      ...      ...         ...         ...
# 726      727       1   1    12        0        4           1           2
# 727      728       1   1    12        0        5           1           2
# 728      729       1   1    12        0        6           0           2
# 729      730       1   1    12        0        0           0           1
# 730      731       1   1    12        0        1           1           2
#
#          temp     atemp       hum  windspeed  casual  registered   cnt
# ...

# %%
collist=df_x.columns.values
ncol=12
nrows=10
plt.subplot?
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sb.boxplot(df_x[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df_x.skew()
# Out:
# instant       0.000000
# season       -0.000384
# yr           -0.002742
# mnth         -0.008149
# holiday       5.654224
# weekday       0.002742
# workingday   -0.793147
# weathersit    0.957385
# temp         -0.054521
# atemp        -0.131088
# hum          -0.069783
# windspeed     0.677345
# casual        1.266454
# registered    0.043659
# cnt          -0.047353
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_x))
z
# Out:
# array([[1.729683  , 1.34821315, 1.00136893, ..., 0.7537338 , 1.9254707 ,
#         1.81795256],
#        [1.72494414, 1.34821315, 1.00136893, ..., 1.04521412, 1.91520896,
#         1.91299949],
#        [1.72020528, 1.34821315, 1.00136893, ..., 1.06124554, 1.5566892 ,
#         1.62992496],
#        ...,
#        [1.72020528, 1.34821315, 0.99863295, ..., 1.00440687, 1.58683308,
#         1.63405743],
#        [1.72494414, 1.34821315, 0.99863295, ..., 0.70563955, 1.42649329,
#         1.39902293],
#        [1.729683  , 1.34821315, 0.99863295, ..., 0.59633443, 0.87620714,
#         0.91707305]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 16,  49,  49,  51,  68, 104, 149, 184, 184, 247, 282, 314, 327,
#        359, 366, 380, 415, 432, 441, 462, 471, 504, 512, 513, 532, 550,
#        611, 623, 644, 646, 681, 691, 724], dtype=int64), array([ 4, 10, 11,  4, 10,  4,  4,  4, 12,  4,  4,  4,  4,  4,  4,  4,  4,
#        11, 12, 12,  4, 12, 12,  4, 12,  4,  4, 12, 12,  4,  4,  4,  4],
#       dtype=int64))

# %%
df_new=df_x[(z<3).all(axis=1)]
df_new
# Out:
#      instant  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0          1       1   0     1        0        6           0           2
# 1          2       1   0     1        0        0           0           2
# 2          3       1   0     1        0        1           1           1
# 3          4       1   0     1        0        2           1           1
# 4          5       1   0     1        0        3           1           1
# ..       ...     ...  ..   ...      ...      ...         ...         ...
# 726      727       1   1    12        0        4           1           2
# 727      728       1   1    12        0        5           1           2
# 728      729       1   1    12        0        6           0           2
# 729      730       1   1    12        0        0           0           1
# 730      731       1   1    12        0        1           1           2
#
#          temp     atemp       hum  windspeed  casual  registered   cnt
# ...

# %%
df_new.skew()
# Out:
# instant       0.014307
# season       -0.014917
# yr            0.017180
# mnth         -0.013480
# holiday       0.000000
# weekday      -0.018876
# workingday   -0.935263
# weathersit    0.933362
# temp         -0.056952
# atemp        -0.131745
# hum           0.074956
# windspeed     0.633474
# casual        1.144156
# registered    0.056654
# cnt          -0.051049
# dtype: float64

# %%
df_x.shape
# Out:
# (731, 15)

# %%
df_new.shape
# Out:
# (700, 15)

# %%
#treating using log
import numpy as np
for col in df_new.columns:
    if df_new.skew().loc[col]>0.45:
        df_new[col]=np.log1p(df_new[col])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_new.skew()
# Out:
# instant       0.014307
# season       -0.014917
# yr            0.017180
# mnth         -0.013480
# holiday       0.000000
# weekday      -0.018876
# workingday   -0.935263
# weathersit    0.677124
# temp         -0.056952
# atemp        -0.131745
# hum           0.074956
# windspeed     0.335849
# casual       -0.963078
# registered    0.056654
# cnt          -0.051049
# dtype: float64

# %%
#separating the input variable
import numpy as np
df_x1=df_new.drop(columns=["cnt"])
y=df_new['cnt']

# %%
sb.pairplot(df_new)
plt.show()

# %%
#sacaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x2=sc.fit_transform(df_x1)
x2=pd.DataFrame(x2,columns=df_x1.columns)

# %%
x2
# Out:
#       instant    season        yr      mnth  holiday   weekday  workingday  \
# 0   -1.722123 -1.362141 -0.991465 -1.607476      0.0  1.500812   -1.570142
# 1   -1.717385 -1.362141 -0.991465 -1.607476      0.0 -1.505106   -1.570142
# 2   -1.712648 -1.362141 -0.991465 -1.607476      0.0 -1.004119    0.636885
# 3   -1.707911 -1.362141 -0.991465 -1.607476      0.0 -0.503133    0.636885
# 4   -1.703174 -1.362141 -0.991465 -1.607476      0.0 -0.002147    0.636885
# ..        ...       ...       ...       ...      ...       ...         ...
# 695  1.717155 -1.362141  1.008608  1.590035      0.0  0.498839    0.636885
# 696  1.721893 -1.362141  1.008608  1.590035      0.0  0.999825    0.636885
# 697  1.726630 -1.362141  1.008608  1.590035      0.0  1.500812   -1.570142
# 698  1.731367 -1.362141  1.008608  1.590035      0.0 -1.505106   -1.570142
# 699  1.736105 -1.362141  1.008608  1.590035      0.0 -1.004119    0.636885
#
# ...

# %%
y.skew()
# Out:
# -0.05104917309618578

# %%
x2.skew()
# Out:
# instant       0.014307
# season       -0.014917
# yr            0.017180
# mnth         -0.013480
# holiday       0.000000
# weekday      -0.018876
# workingday   -0.935263
# weathersit    0.677124
# temp         -0.056952
# atemp        -0.131745
# hum           0.074956
# windspeed     0.335849
# casual       -0.963078
# registered    0.056654
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x2,y,random_state = 55,test_size=0.20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x2,y):
    max_r_score=-10
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test = train_test_split(x2,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ", final_r_state,"is",max_r_score)
    return final_r_state

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 6}

# %%
#knn max r2 score
knr=KNeighborsRegressor(n_neighbors=6)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.9834688476223409
# r2_score corresponding to random state:  43 is:  0.9743508842990081
# r2_score corresponding to random state:  44 is:  0.9806229174144596
# r2_score corresponding to random state:  45 is:  0.9726645340078538
# r2_score corresponding to random state:  46 is:  0.9692882505418117
# r2_score corresponding to random state:  47 is:  0.972155792044014
# r2_score corresponding to random state:  48 is:  0.9747663834307941
# r2_score corresponding to random state:  49 is:  0.9758006513109342
# r2_score corresponding to random state:  50 is:  0.9717762998609859
# r2_score corresponding to random state:  51 is:  0.9682657935522359
# r2_score corresponding to random state:  52 is:  0.9614648689846661
# r2_score corresponding to random state:  53 is:  0.9816725887266563
# r2_score corresponding to random state:  54 is:  0.9710849538482602
# r2_score corresponding to random state:  55 is:  0.977131644267914
# ...

# %%
from sklearn.linear_model import LinearRegression
lrreg=LinearRegression()
r_state=maxr2_score(lrreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.9834688476223409
# r2_score corresponding to random state:  43 is:  0.9743508842990081
# r2_score corresponding to random state:  44 is:  0.9806229174144596
# r2_score corresponding to random state:  45 is:  0.9726645340078538
# r2_score corresponding to random state:  46 is:  0.9692882505418117
# r2_score corresponding to random state:  47 is:  0.972155792044014
# r2_score corresponding to random state:  48 is:  0.9747663834307941
# r2_score corresponding to random state:  49 is:  0.9758006513109342
# r2_score corresponding to random state:  50 is:  0.9717762998609859
# r2_score corresponding to random state:  51 is:  0.9682657935522359
# r2_score corresponding to random state:  52 is:  0.9614648689846661
# r2_score corresponding to random state:  53 is:  0.9816725887266563
# r2_score corresponding to random state:  54 is:  0.9710849538482602
# r2_score corresponding to random state:  55 is:  0.977131644267914
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lrreg,x2,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression:",cross_val_score(lrreg,x2,y,cv=5,scoring='r2').std())
print()
print("Mean r2 score for KNN Regression: ",cross_val_score(knr,x2,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression:",cross_val_score(knr,x2,y,cv=5,scoring="r2").std())
# based on output Linear Regression is Performing well
# Out:
# Mean r2 score for Linear Regression: 0.8991036636153812
# standard deviation in r2 score for Linear Regression: 0.035721190242265534
#
# Mean r2 score for KNN Regression:  0.19330946832584012
# standard deviation in r2 score for KNN Regression: 0.355660999600278

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x2,y)
clf.best_params_
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19562940.823295914, tolerance: 185111.24172079362
#   positive)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24210769.481146418, tolerance: 235409.17065714288
#   positive)
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24931767.40344566, tolerance: 251783.2105593651
#   positive)
# ...

# %%
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,x2,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.9834688476223409
# r2_score corresponding to random state:  43 is:  0.9743508842990081
# r2_score corresponding to random state:  44 is:  0.9806229174144596
# r2_score corresponding to random state:  45 is:  0.9726645340078538
# r2_score corresponding to random state:  46 is:  0.9692882505418117
# r2_score corresponding to random state:  47 is:  0.972155792044014
# r2_score corresponding to random state:  48 is:  0.9747663834307941
# r2_score corresponding to random state:  49 is:  0.9758006513109342
# r2_score corresponding to random state:  50 is:  0.9717762998609859
# r2_score corresponding to random state:  51 is:  0.9682657935522359
# r2_score corresponding to random state:  52 is:  0.9614648689846661
# r2_score corresponding to random state:  53 is:  0.9816725887266563
# r2_score corresponding to random state:  54 is:  0.9710849538482602
# r2_score corresponding to random state:  55 is:  0.977131644267914
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x2,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression:",cross_val_score(lsreg,x2,y,cv=5,scoring='r2').std())
# based on output Lasso Regression is Performing as linear Regression
# Out:
# Mean r2 score for Lasso Regression: 0.9007879911573852
# standard deviation in r2 score for Lasso Regression: 0.03483638442297694

# %%
# gradient Boosting
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x2,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Gradientboosting Regressor:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(gbr,x2,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradientboosting Regressor: 0.9701635285639707
# standard deviation in r2 score for GradientbootingRegressir: 0.020454367480644487

# %%
# use of boosting i will save linear regression model for production
#worked on all models linear regression is best no changes even after boosting and crossvalidation
#random state correnponding to highest r2_score is 82
x_train,x_test,y_train,y_test=train_test_split(x2,y,random_state=93,test_size=20)
lrreg=LinearRegression()
lrreg.fit(x_train,y_train)
y_pred=lrreg.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE is',np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2 score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is 174.30056412653815
# r2 score is: 0.9910617275398899

# %%
from sklearn.externals import joblib
joblib.dump(lrreg,'project5_lrreg.pkl')
# Out:
# ['project5_lrreg.pkl']
