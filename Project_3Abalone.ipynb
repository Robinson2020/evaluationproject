# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('abalone.csv',delimiter=',',header=None)
df
# Out:
#       0      1      2      3       4       5       6       7   8
# 0     M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  15
# 1     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 2     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 3     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 4     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4172  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4173  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4174  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4175  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4176  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4177 rows x 9 columns]

# %%
column_labels=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']
df.columns=column_labels

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
dfcor=df.corr()
dfcor
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %%
df['Length'].plot.box()

# %%
collist=df.columns.values
ncol=14
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
sns.distplot(df['Whole weight'])

# %%
sns.distplot(df['Height'])

# %%
df.skew
# Out:
# <bound method DataFrame.skew of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]>

# %%
plt.scatter(df['Length'],df['Rings'])

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
Le=LabelEncoder()
df['Sex']=Le.fit_transform(df['Sex'])
df['Sex']
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.skew
# Out:
# <bound method DataFrame.skew of       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]>

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
#        2436, 2459, 2471, 2544, 2623, 2624, 2624, 2624, 2625, 2709, 2710,
#        2710, 2810, 2810, 2811, 2811, 2811, 2862, 2863, 2863, 2863, 3007,
#        3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193, 3280, 3359,
#        3427, 3427, 3427, 3599, 3599, 3628, 3713, 3715, 3715, 3715, 3715,
#        3800, 3837, 3899, 3899, 3902, 3924, 3930, 3944, 3961, 3962, 3996,
#        4145, 4148], dtype=int64), array([8, 8, 7, 8, 7, 7, 7, 4, 5, 7, 7, 8, 8, 7, 6, 8, 8, 1, 2, 3, 1, 2,
#        1, 2, 1, 8, 8, 7, 8, 8, 8, 8, 8, 7, 8, 8, 4, 7, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 8, 1, 2, 8, 8, 8, 8, 8, 8, 8, 2, 1, 2, 1, 2, 1, 2, 8,
#        8, 8, 8, 4, 5, 7, 6, 4, 5, 4, 5, 5, 5, 5, 6, 5, 6, 4, 5, 6, 7, 4,
#        5, 3, 3, 5, 5, 6, 5, 4, 5, 6, 7, 1, 2, 5, 5, 5, 6, 6, 5, 4, 5, 6,
#        4, 5, 6, 5, 5, 1, 1, 2, 3, 7, 7, 8, 1, 2, 7, 7, 8, 8, 8, 8, 7, 8,
#        7, 8, 8, 4, 6, 8, 8, 8, 8, 7, 1, 8, 8, 8, 5, 4, 4, 5, 6, 5, 6, 5,
#        6, 5, 6, 4, 5, 6, 5, 4, 5, 6, 5, 7, 8, 7, 7, 8, 7, 8, 7, 8, 8, 8,
#        4, 5, 6, 4, 5, 6, 5, 4, 5, 6, 7, 4, 2, 1, 2, 1, 8, 8, 8, 5, 5, 3,
#        7, 6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4027 rows x 9 columns]

# %%
df.shape
# Out:
# (4177, 9)

# %%
df_new.shape
# Out:
# (4027, 9)

# %%
df_new.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %%
#treating using log
import numpy as np
for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
df_new.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings            -0.158078
# dtype: float64

# %%
sns.pairplot(df_new)
plt.show()

# %%
#separating the input variable
import numpy as np
df_x=df_new.drop(columns=["Rings"])
y=df_new['Rings']

# %%
#sacaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.skew()
x
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.159698 -0.569368 -0.420274 -1.166207     -0.633156       -0.603733
# 1     1.159698 -1.475358 -1.463127 -1.301806     -1.265644       -1.209410
# 2    -1.285382  0.077768  0.153294 -0.081420     -0.275805       -0.448680
# 3     1.159698 -0.698795 -0.420274 -0.352617     -0.628771       -0.647342
# 4    -0.062842 -1.647928 -1.567412 -1.573003     -1.310587       -1.257865
# ...        ...       ...       ...       ...           ...             ...
# 4022 -1.285382  0.379764  0.466150  0.732171      0.184584        0.101275
# 4023  1.159698  0.595476  0.361865 -0.081420      0.357779        0.435609
# 4024  1.159698  0.681761  0.726863  1.816959      0.818169        0.854737
# 4025 -1.285382  0.897473  0.831148  0.325376      0.639493        0.881387
# 4026  1.159698  1.630893  1.561145  1.545762      2.511746        2.889812
#
#       Viscera weight  Shell weight
# 0          -0.723057     -0.630659
# 1          -1.231104     -1.256033
# 2          -0.331135     -0.161629
# 3          -0.597255     -0.591574
# 4          -1.318198     -1.373290
# ...              ...           ...
# 4022        0.612382      0.143240
# 4023        0.375293      0.233138
# 4024        1.081721      0.604453
# 4025        0.825278      0.510647
# 4026        1.942982      2.066264
#
# [4027 rows x 8 columns]

# %%
y.skew()
# Out:
# -0.1580776424098459

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 55,test_size=0.20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=-10
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ", final_r_state,"is",max_r_score)
    return final_r_state

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 18}

# %%
from sklearn.linear_model import LinearRegression
lrreg=LinearRegression()
r_state=maxr2_score(lrreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.5530142636861288
# r2_score corresponding to random state:  43 is:  0.5607156885698377
# r2_score corresponding to random state:  44 is:  0.5695063523391657
# r2_score corresponding to random state:  45 is:  0.6101819231348589
# r2_score corresponding to random state:  46 is:  0.5496271234540689
# r2_score corresponding to random state:  47 is:  0.5702612121639696
# r2_score corresponding to random state:  48 is:  0.5463766062150048
# r2_score corresponding to random state:  49 is:  0.590091792093101
# r2_score corresponding to random state:  50 is:  0.5782286761324478
# r2_score corresponding to random state:  51 is:  0.5930239670300373
# r2_score corresponding to random state:  52 is:  0.5506454691012643
# r2_score corresponding to random state:  53 is:  0.49807423566858056
# r2_score corresponding to random state:  54 is:  0.5470758552475428
# r2_score corresponding to random state:  55 is:  0.5665111739631987
# r2_score corresponding to random state:  56 is:  0.5375294464760452
# r2_score corresponding to random state:  57 is:  0.5888711319959758
# r2_score corresponding to random state:  58 is:  0.5768657160282438
# r2_score corresponding to random state:  59 is:  0.5863918835199036
# r2_score corresponding to random state:  60 is:  0.5772816327611006
# r2_score corresponding to random state:  61 is:  0.5418115098156457
# r2_score corresponding to random state:  62 is:  0.6069958445408292
# r2_score corresponding to random state:  63 is:  0.5346100309377423
# r2_score corresponding to random state:  64 is:  0.5583617308142053
# r2_score corresponding to random state:  65 is:  0.5793618664494677
# r2_score corresponding to random state:  66 is:  0.5812396725782014
# r2_score corresponding to random state:  67 is:  0.5571896792977774
# r2_score corresponding to random state:  68 is:  0.5543204380925463
# r2_score corresponding to random state:  69 is:  0.5849307170569762
# r2_score corresponding to random state:  70 is:  0.5688574122249705
# r2_score corresponding to random state:  71 is:  0.5703944617435672
# r2_score corresponding to random state:  72 is:  0.5919352018345676
# r2_score corresponding to random state:  73 is:  0.5829705771177223
# r2_score corresponding to random state:  74 is:  0.5880820567628939
# r2_score corresponding to random state:  75 is:  0.5683463684744828
# r2_score corresponding to random state:  76 is:  0.5633029654230763
# r2_score corresponding to random state:  77 is:  0.5556780333250422
# r2_score corresponding to random state:  78 is:  0.569615950770689
# r2_score corresponding to random state:  79 is:  0.577435622473395
# r2_score corresponding to random state:  80 is:  0.5784978954675855
# r2_score corresponding to random state:  81 is:  0.6005647285629914
# r2_score corresponding to random state:  82 is:  0.6121119510047253
# r2_score corresponding to random state:  83 is:  0.5456390440884635
# r2_score corresponding to random state:  84 is:  0.5338214987843158
# r2_score corresponding to random state:  85 is:  0.5388645247173712
# r2_score corresponding to random state:  86 is:  0.5779411126461586
# r2_score corresponding to random state:  87 is:  0.5560066831225998
# r2_score corresponding to random state:  88 is:  0.568944137096367
# r2_score corresponding to random state:  89 is:  0.5701548425328331
# r2_score corresponding to random state:  90 is:  0.5891944766761028
# r2_score corresponding to random state:  91 is:  0.5581535152253284
# r2_score corresponding to random state:  92 is:  0.5828700604679379
# r2_score corresponding to random state:  93 is:  0.5439770522320406
# r2_score corresponding to random state:  94 is:  0.5590996634779439
# r2_score corresponding to random state:  95 is:  0.5868362310141586
# r2_score corresponding to random state:  96 is:  0.5591783879950759
# r2_score corresponding to random state:  97 is:  0.587671499542545
# r2_score corresponding to random state:  98 is:  0.5889343632390676
# r2_score corresponding to random state:  99 is:  0.5832312162718537
# r2_score corresponding to random state:  100 is:  0.5648532138306874
# max r2 score corresponding to  82 is 0.6121119510047253

# %%
#knn max r2 score
knr=KNeighborsRegressor(n_neighbors=18)
r_state=maxr2_score(knr,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.5530142636861288
# r2_score corresponding to random state:  43 is:  0.5607156885698377
# r2_score corresponding to random state:  44 is:  0.5695063523391657
# r2_score corresponding to random state:  45 is:  0.6101819231348589
# r2_score corresponding to random state:  46 is:  0.5496271234540689
# r2_score corresponding to random state:  47 is:  0.5702612121639696
# r2_score corresponding to random state:  48 is:  0.5463766062150048
# r2_score corresponding to random state:  49 is:  0.590091792093101
# r2_score corresponding to random state:  50 is:  0.5782286761324478
# r2_score corresponding to random state:  51 is:  0.5930239670300373
# r2_score corresponding to random state:  52 is:  0.5506454691012643
# r2_score corresponding to random state:  53 is:  0.49807423566858056
# r2_score corresponding to random state:  54 is:  0.5470758552475428
# r2_score corresponding to random state:  55 is:  0.5665111739631987
# r2_score corresponding to random state:  56 is:  0.5375294464760452
# r2_score corresponding to random state:  57 is:  0.5888711319959758
# r2_score corresponding to random state:  58 is:  0.5768657160282438
# r2_score corresponding to random state:  59 is:  0.5863918835199036
# r2_score corresponding to random state:  60 is:  0.5772816327611006
# r2_score corresponding to random state:  61 is:  0.5418115098156457
# r2_score corresponding to random state:  62 is:  0.6069958445408292
# r2_score corresponding to random state:  63 is:  0.5346100309377423
# r2_score corresponding to random state:  64 is:  0.5583617308142053
# r2_score corresponding to random state:  65 is:  0.5793618664494677
# r2_score corresponding to random state:  66 is:  0.5812396725782014
# r2_score corresponding to random state:  67 is:  0.5571896792977774
# r2_score corresponding to random state:  68 is:  0.5543204380925463
# r2_score corresponding to random state:  69 is:  0.5849307170569762
# r2_score corresponding to random state:  70 is:  0.5688574122249705
# r2_score corresponding to random state:  71 is:  0.5703944617435672
# r2_score corresponding to random state:  72 is:  0.5919352018345676
# r2_score corresponding to random state:  73 is:  0.5829705771177223
# r2_score corresponding to random state:  74 is:  0.5880820567628939
# r2_score corresponding to random state:  75 is:  0.5683463684744828
# r2_score corresponding to random state:  76 is:  0.5633029654230763
# r2_score corresponding to random state:  77 is:  0.5556780333250422
# r2_score corresponding to random state:  78 is:  0.569615950770689
# r2_score corresponding to random state:  79 is:  0.577435622473395
# r2_score corresponding to random state:  80 is:  0.5784978954675855
# r2_score corresponding to random state:  81 is:  0.6005647285629914
# r2_score corresponding to random state:  82 is:  0.6121119510047253
# r2_score corresponding to random state:  83 is:  0.5456390440884635
# r2_score corresponding to random state:  84 is:  0.5338214987843158
# r2_score corresponding to random state:  85 is:  0.5388645247173712
# r2_score corresponding to random state:  86 is:  0.5779411126461586
# r2_score corresponding to random state:  87 is:  0.5560066831225998
# r2_score corresponding to random state:  88 is:  0.568944137096367
# r2_score corresponding to random state:  89 is:  0.5701548425328331
# r2_score corresponding to random state:  90 is:  0.5891944766761028
# r2_score corresponding to random state:  91 is:  0.5581535152253284
# r2_score corresponding to random state:  92 is:  0.5828700604679379
# r2_score corresponding to random state:  93 is:  0.5439770522320406
# r2_score corresponding to random state:  94 is:  0.5590996634779439
# r2_score corresponding to random state:  95 is:  0.5868362310141586
# r2_score corresponding to random state:  96 is:  0.5591783879950759
# r2_score corresponding to random state:  97 is:  0.587671499542545
# r2_score corresponding to random state:  98 is:  0.5889343632390676
# r2_score corresponding to random state:  99 is:  0.5832312162718537
# r2_score corresponding to random state:  100 is:  0.5648532138306874
# max r2 score corresponding to  82 is 0.6121119510047253

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression:",cross_val_score(lrreg,x,y,cv=5,scoring='r2').std())
print()
print("Mean r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression:",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# based on output KNN Regression is Performing well
# Out:
# Mean r2 score for Linear Regression: 0.49685045620224394
# standard deviation in r2 score for Linear Regression: 0.06851087260356867
#
# Mean r2 score for KNN Regression:  0.540926995202868
# standard deviation in r2 score for KNN Regression: 0.06458025385744696

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2_score corresponding to random state:  42 is:  0.5530142636861288
# r2_score corresponding to random state:  43 is:  0.5607156885698377
# r2_score corresponding to random state:  44 is:  0.5695063523391657
# r2_score corresponding to random state:  45 is:  0.6101819231348589
# r2_score corresponding to random state:  46 is:  0.5496271234540689
# r2_score corresponding to random state:  47 is:  0.5702612121639696
# r2_score corresponding to random state:  48 is:  0.5463766062150048
# r2_score corresponding to random state:  49 is:  0.590091792093101
# r2_score corresponding to random state:  50 is:  0.5782286761324478
# r2_score corresponding to random state:  51 is:  0.5930239670300373
# r2_score corresponding to random state:  52 is:  0.5506454691012643
# r2_score corresponding to random state:  53 is:  0.49807423566858056
# r2_score corresponding to random state:  54 is:  0.5470758552475428
# r2_score corresponding to random state:  55 is:  0.5665111739631987
# r2_score corresponding to random state:  56 is:  0.5375294464760452
# r2_score corresponding to random state:  57 is:  0.5888711319959758
# r2_score corresponding to random state:  58 is:  0.5768657160282438
# r2_score corresponding to random state:  59 is:  0.5863918835199036
# r2_score corresponding to random state:  60 is:  0.5772816327611006
# r2_score corresponding to random state:  61 is:  0.5418115098156457
# r2_score corresponding to random state:  62 is:  0.6069958445408292
# r2_score corresponding to random state:  63 is:  0.5346100309377423
# r2_score corresponding to random state:  64 is:  0.5583617308142053
# r2_score corresponding to random state:  65 is:  0.5793618664494677
# r2_score corresponding to random state:  66 is:  0.5812396725782014
# r2_score corresponding to random state:  67 is:  0.5571896792977774
# r2_score corresponding to random state:  68 is:  0.5543204380925463
# r2_score corresponding to random state:  69 is:  0.5849307170569762
# r2_score corresponding to random state:  70 is:  0.5688574122249705
# r2_score corresponding to random state:  71 is:  0.5703944617435672
# r2_score corresponding to random state:  72 is:  0.5919352018345676
# r2_score corresponding to random state:  73 is:  0.5829705771177223
# r2_score corresponding to random state:  74 is:  0.5880820567628939
# r2_score corresponding to random state:  75 is:  0.5683463684744828
# r2_score corresponding to random state:  76 is:  0.5633029654230763
# r2_score corresponding to random state:  77 is:  0.5556780333250422
# r2_score corresponding to random state:  78 is:  0.569615950770689
# r2_score corresponding to random state:  79 is:  0.577435622473395
# r2_score corresponding to random state:  80 is:  0.5784978954675855
# r2_score corresponding to random state:  81 is:  0.6005647285629914
# r2_score corresponding to random state:  82 is:  0.6121119510047253
# r2_score corresponding to random state:  83 is:  0.5456390440884635
# r2_score corresponding to random state:  84 is:  0.5338214987843158
# r2_score corresponding to random state:  85 is:  0.5388645247173712
# r2_score corresponding to random state:  86 is:  0.5779411126461586
# r2_score corresponding to random state:  87 is:  0.5560066831225998
# r2_score corresponding to random state:  88 is:  0.568944137096367
# r2_score corresponding to random state:  89 is:  0.5701548425328331
# r2_score corresponding to random state:  90 is:  0.5891944766761028
# r2_score corresponding to random state:  91 is:  0.5581535152253284
# r2_score corresponding to random state:  92 is:  0.5828700604679379
# r2_score corresponding to random state:  93 is:  0.5439770522320406
# r2_score corresponding to random state:  94 is:  0.5590996634779439
# r2_score corresponding to random state:  95 is:  0.5868362310141586
# r2_score corresponding to random state:  96 is:  0.5591783879950759
# r2_score corresponding to random state:  97 is:  0.587671499542545
# r2_score corresponding to random state:  98 is:  0.5889343632390676
# r2_score corresponding to random state:  99 is:  0.5832312162718537
# r2_score corresponding to random state:  100 is:  0.5648532138306874
# max r2 score corresponding to  82 is 0.6121119510047253

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
# based on output Lasso Regression is Performing as linear Regression
# Out:
# Mean r2 score for Lasso Regression: 0.49370639192040305
# standard deviation in r2 score for Lasso Regression: 0.07141129886889097

# %%
# gradient Boosting
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Gradientboosting Regressor:",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradientboosting Regressor: 0.5696350567428342
# standard deviation in r2 score for GradientbootingRegressir: 0.054528626914393044

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lrreg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)            
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 1000}

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Gradientboosting Regressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for GradientbootingRegressir:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradientboosting Regressor: 0.4152792116839789
# standard deviation in r2 score for GradientbootingRegressir: 0.15448500608307933

# %%
#worked on all models linear regression is best no changes even after boosting and crossvalidation
#random state correnponding to highest r2_score is 82
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=82,test_size=20)
lrreg=LinearRegression()
lrreg.fit(x_train,y_train)
y_pred=lrreg.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE is',np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2 score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is 0.15094539648973487
# r2 score is: 0.631594704932074

# %%
from sklearn.externals import joblib
joblib.dump(lrreg,'project2_lrreg.pkl')
# Out:
# ['project2_lrreg.pkl']
